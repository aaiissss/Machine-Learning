# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
Path="/content/drive/MyDrive/Praktikum_ML/Praktikum02"

# %%
import pandas as pd
df = pd.read_csv(Path + '/Data/day.csv')
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# Hitung ukuran split
total_size = len(df)
train_size = int(total_size * 0.8)
test_size = int(total_size * 0.2)

# Menampilkan hasil
print("Jumlah data Training:", len(train_df))
print("Jumlah data Validation:", len(val_df))
print("Jumlah data Testing:", len(test_df))
# Out:
# Jumlah data Training: 526
# Jumlah data Validation: 59
# Jumlah data Testing: 146

# %%
# Membagi data menjadi set pelatihan dan pengujian (80% pelatihan, 20% pengujian)
train_df, test_df = train_test_split(df, test_size=test_size, random_state=42)

# Membagi data pelatihan lebih lanjut menjadi set pelatihan dan validasi (90% pelatihan, 10% validasi dari train_df awal)
train_df, val_df = train_test_split(train_df, test_size=0.1, random_state=42)

print("\n5 baris data teratas Data Training:")
display(train_df.head())

print("\n5 baris data teratas Data Validation:")
display(val_df.head())

print("\n5 baris data teratas Data Testing:")
display(test_df.head())
# Out:
# 5 baris data teratas Data Training:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 674      675  2012-11-05       4   1    11        0        1           1
# 685      686  2012-11-16       4   1    11        0        5           1
# 12        13  2011-01-13       1   0     1        0        4           1
# 638      639  2012-09-30       4   1     9        0        0           0
# 431      432  2012-03-07       1   1     3        0        3           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 674           1  0.319167  0.308075  0.494167   0.236325     378        4881
# 685           1  0.345000  0.347204  0.524583   0.171025     484        5214
# 12            1  0.165000  0.150883  0.470417   0.301000      38        1368
# 638           1  0.526667  0.517663  0.583333   0.134958    2015        4874
# 431           1  0.404167  0.385100  0.513333   0.345779     432        4484
#
#       cnt
# 674  5259
# ...

# %%
import matplotlib.pyplot as plt

sizes = [len(train_df), len(val_df), len(test_df)]
labels = ['Training', 'Validation', 'Testing']

plt.figure(figsize=(5,5))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Proporsi Pembagian Dataset")
plt.show()
